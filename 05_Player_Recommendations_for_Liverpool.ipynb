# %%
## 패키지 import

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
## 'data_modified'에서 전치리된 csv파일을 읽어와서 분석해주십시오.
## 담당자: 안명진
data = pd.read_csv('data/FIFA22_official_data.csv')

# %%
market=data[(data['Best Position']=='CDM')&(data['Club']!='Liverpool')&(data['Overall']>=83)]
market['Point']=(market['Overall']*2+market['Potential'])/market['Age']

# %%
# 영입 조건을 만족하는 선수들 명단
want = market[['Name','Club','Age','Overall','Potential','Value','Point','Joined']]
want
# Out:
#                 Name               Club  Age  Overall  Potential   Value  \
# 5         J. Kimmich  FC Bayern München   26       89         90   €108M
# 28          Casemiro     Real Madrid CF   29       89         89    €88M
# 41       M. Brozović              Inter   28       84         84    €37M
# 51         F. Kessié           AC Milan   24       84         86  €49.5M
# 71          N. Kanté            Chelsea   30       90         90   €100M
# 94         A. Witsel  Borussia Dortmund   32       83         83    €24M
# 142      Fernandinho    Manchester City   36       83         83     €7M
# 166            Allan            Everton   30       83         83  €30.5M
# 265            Rodri    Manchester City   25       86         89    €81M
# 292      P. Højbjerg  Tottenham Hotspur   25       83         86  €43.5M
# 542         Fernando         Sevilla FC   33       84         84    €21M
# 804  Sergio Busquets       FC Barcelona   32       86         86    €45M
#
#          Point        Joined
# 5    10.307692   Jul 1, 2015
# 28    9.206897  Jul 11, 2013
# 41    9.000000   Jul 1, 2016
# 51   10.583333   Jul 1, 2019
# 71    9.000000  Jul 16, 2016
# 94    7.781250  Aug 17, 2018
# 142   6.916667   Jul 1, 2013
# 166   8.300000   Sep 5, 2020
# 265  10.440000   Jul 4, 2019
# 292  10.080000  Aug 11, 2020
# 542   7.636364  Jul 12, 2019
# 804   8.062500   Sep 1, 2008

# %%
# 명단 시각화
fig, ax = plt.subplots(nrows=2,ncols=2)

fig.set_size_inches((12,8))
plt.subplots_adjust(wspace = 0.4, hspace = 0.2)

sns.barplot(data=want, x='Age', y='Name', palette='viridis', ax=ax[0,0])
sns.barplot(data=want, x='Overall', y='Name', palette='viridis', ax=ax[0,1])
sns.barplot(data=want, x='Potential', y='Name', palette='viridis', ax=ax[1,0])
sns.barplot(data=want, x='Point', y='Name', palette='viridis', ax=ax[1,1])
# Out:
# <Axes: xlabel='Point', ylabel='Name'>
